# %% [markdown]
# <a href="https://colab.research.google.com/github/Akanksha647/rag-colab-project/blob/main/copy_of_untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Akanksha647/rag-colab-project.git
# Out:
# fatal: destination path 'rag-colab-project' already exists and is not an empty directory.

# %%
# %cd rag-colab-project
# Out:
# /content/rag-colab-project

# %%
# !pip install -r requirements.txt

# %%
# !python rag_app.py
# Out:
# /content/rag-colab-project/rag_app.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 4227.09it/s]
# Loading weights: 100% 282/282 [00:00<00:00, 3923.46it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# ...
